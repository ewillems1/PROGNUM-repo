# %% [markdown]
# Answers for Week 1
#
# * Name: Enola Willems
# * Username: ewillems
# * Student s-number: S6420494
# * Group (AS1, etc.): AS6

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![cactus.jpg](attachment:cactus.jpg)

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1
print(x)
# Out:
# 720

# %%
from scipy.constants import h
from scipy.constants import c
E=h*2.42e28
print(E)
# Out:
# 1.6035089763e-05

# %%
m=7.342e22
M=5.9722e24
r=385000.6e3
from scipy.constants import G
F=(G*M*m)/(r**2)
print(F)
# Out:
# 1.9743840518075715e+20

# %% [markdown]
# Question 1.15:
# 1) It prints the absolute path to Downloads: /Users/users/ewillems/Downloads
# 2) cd . takes us to the current directory and cd .. takes us to the parent directory (oneup) so from Downloads to the home directory

# %% [markdown]
# Question 1.16:
#
# cd ~/Desktop

# %% [markdown]
# Question 1.19:
# 1) ls * [0-9] *.[co] means that it shows the files with the numbers ranging from 0-9 and a c or an o.
# 2) the square brackets [and] mean it shows the files with a, n or d
# 3) The difference for this command is that the it shows the files with the numbers ranging from 0-9 and co
